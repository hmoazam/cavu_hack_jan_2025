# %%
# %run ./00_config

# %% [markdown]
# ## Ingest json and write to delta

# %%
FILE_NAME = "dummy_qna.json"
TABLE_NAME = "qna_raw"

# %%
df = spark.read.json(f"/Volumes/hannamoazam_catalog/cookbook/source_docs/{FILE_NAME}", multiLine=True)
display(df)

# %%
table_name = table_name = f"{UC_CATALOG}.{UC_SCHEMA}.{TABLE_NAME}"
df.write.format("delta").saveAsTable(table_name)

# %%
spark.sql(f"ALTER TABLE {table_name} SET TBLPROPERTIES (delta.enableChangeDataCapture = true)")
